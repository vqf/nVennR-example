# %%
install.packages("nVennR", dependencies = T)
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
# also installing the dependencies ‘XML’, ‘jpeg’, ‘rsvg’, ‘grImport2’

# %%
library(nVennR)

# %%
myV <- plotVenn(list(a=c(1, 2, 3), b=c(1, 4, 6, 7), c=c(1, 3, 5), d=c(1, 4, 6, 9)))
# Out:
# plot without title

# %%
listVennRegions(myV)
# Out:
# $`0, 0, 0, 1 (d)`
# [1] 9
#
# $`0, 0, 1, 0 (c)`
# [1] 5
#
# $`0, 1, 0, 0 (b)`
# [1] 7
#
# $`0, 1, 0, 1 (b, d)`
# [1] 4 6
#
# $`1, 0, 0, 0 (a)`
# [1] 2
#
# $`1, 0, 1, 0 (a, c)`
# [1] 3
#
# $`1, 1, 1, 1 (a, b, c, d)`
# [1] 1
